# %%
def over_filter(df,min_over=1,max_over=20):
    temp_df = df[(df['ball']>(min_over-1)) & (df['ball']<=max_over)]
    return temp_df

def h2h_filter(df_filt,player_df,batsman="MS Dhoni"):
    df_batsman = df_filt[df_filt['striker'] == batsman]
    bat_h2h = df_batsman.groupby(['bowler'])["runs_off_bat"].agg(balls_faced="count",runs_total="sum").reset_index()
    bat_h2h["dismissals"] = df_batsman.groupby(['bowler'])["player_dismissed"].agg(balls_faced="count",dismissals="count").reset_index()["dismissals"]
    bat_h2h.sort_values(by = 'balls_faced',inplace=True,ascending=False)
    bat_h2h.rename({'bowler':'unique_name'},axis=1,inplace=True)
    bat_h2h_bowl = bat_h2h.merge(player_df,how='left',on='unique_name').drop(columns=['team','identifier','key_cricinfo','batting_style','name','player_type','season','Unnamed: 0'])
    bat_h2h_bowl.drop_duplicates(inplace=True)
    bat_h2h_bowl["strike_rate"] = (bat_h2h_bowl["runs_total"]*100/bat_h2h_bowl["balls_faced"])
    bat_h2h_bowl["balls_per_out"] = (bat_h2h_bowl["balls_faced"]/bat_h2h_bowl["dismissals"])
    bat_h2h_bowl.sort_values(by = 'balls_faced',inplace=True,ascending=False)
    bat_h2h_bowl = bat_h2h_bowl.round({'strike_rate':2,'balls_per_out':1})
    bat_h2h_style = bat_h2h_bowl.groupby(['bowling_style'])["balls_faced"].agg(balls_faced="sum").reset_index()
    bat_h2h_style["runs_total"] = bat_h2h_bowl.groupby(['bowling_style'])["runs_total"].agg(runs_total="sum").reset_index()["runs_total"]
    bat_h2h_style["dismissals"] = bat_h2h_bowl.groupby(['bowling_style'])["dismissals"].agg(dismissals="sum").reset_index()["dismissals"]
    bat_h2h_style.sort_values(by = 'balls_faced',inplace=True,ascending=False)
    bat_h2h_style["strike_rate"] = (bat_h2h_style["runs_total"]*100/bat_h2h_style["balls_faced"])
    bat_h2h_style["balls_per_out"] = (bat_h2h_style["balls_faced"]/bat_h2h_style["dismissals"])
    bat_h2h_style = bat_h2h_style.round({'strike_rate':2,'balls_per_out':1})

    return bat_h2h_bowl,bat_h2h_style



def player_charting(player = "MS Dhoni"):
    #importing relevant modules
    import pandas as pd
    import numpy as np
    import os

    cwd = os.getcwd()
    
    df = pd.read_csv(cwd+"/data/all_matches.csv",dtype = {'match_id':'int', 'season':'str','innings':'int', 'ball':'float'},parse_dates=True)
    df.season = df.season.replace({"2007/08": "2008","2009/10": "2010","2020/21":"2020"})

    players = pd.read_csv("player_details.csv")

    chart_df_pp_bowl , chart_df_pp_style = h2h_filter(over_filter(df = df,min_over=1,max_over=6),players,batsman=player)

    chart_df_mid_bowl , chart_df_mid_style = h2h_filter(over_filter(df = df,min_over=7,max_over=15),players,batsman=player)

    chart_df_death_bowl,chart_df_death_style = h2h_filter(over_filter(df = df,min_over=16,max_over=20),players,batsman=player)

    return chart_df_pp_bowl,chart_df_mid_bowl,chart_df_death_bowl,chart_df_pp_style,chart_df_mid_style,chart_df_death_style

# %%
chart_df_pp_bowl,chart_df_mid_bowl,chart_df_death_bowl,chart_df_pp_style,chart_df_mid_style,chart_df_death_style = player_charting("MS Dhoni")

# %%
chart_df_pp_bowl["balls_faced"].sum()
# Out:
# 71

# %%
chart_df_mid_bowl["balls_faced"].sum()
# Out:
# 1869

# %%
chart_df_death_bowl["balls_faced"].sum()
# Out:
# 1773

# %%
chart_df_pp_style["balls_faced"].sum()
# Out:
# 71

# %%
chart_df_mid_style["balls_faced"].sum()
# Out:
# 1869

# %%
chart_df_death_style["balls_faced"].sum()
# Out:
# 1773

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_8535/2397878543.py in <module>
# ----> 1 df_batsman = df[df['striker'] == "MS Dhoni"]
#
# NameError: name 'df' is not defined

# %%
    #importing relevant modules
    import pandas as pd
    import numpy as np
    import os

    cwd = os.getcwd()
    
    df = pd.read_csv(cwd+"/data/all_matches.csv",dtype = {'match_id':'int', 'season':'str','innings':'int', 'ball':'float'},parse_dates=True)
    df.season = df.season.replace({"2007/08": "2008","2009/10": "2010","2020/21":"2020"})

    players = pd.read_csv("player_details.csv")

# %%
df_batsman = df[df['striker'] == "V Kohli"]

# %%
df_batsman.count()
# Out:
# match_id                  5124
# season                    5124
# start_date                5124
# venue                     5124
# innings                   5124
# ball                      5124
# batting_team              5124
# bowling_team              5124
# striker                   5124
# non_striker               5124
# bowler                    5124
# runs_off_bat              5124
# extras                    5124
# wides                      125
# noballs                     18
# byes                         4
# legbyes                     41
# penalty                      0
# wicket_type                186
# player_dismissed           186
# other_wicket_type            0
# other_player_dismissed       0
# dtype: int64

# %%
df_batsman[df_batsman["wides"].isna()]
# Out:
#         match_id season  start_date                      venue  innings  ball  \
# 132       335982   2008  2008-04-18      M Chinnaswamy Stadium        2   1.2
# 133       335982   2008  2008-04-18      M Chinnaswamy Stadium        2   1.3
# 134       335982   2008  2008-04-18      M Chinnaswamy Stadium        2   1.4
# 137       335982   2008  2008-04-18      M Chinnaswamy Stadium        2   2.1
# 138       335982   2008  2008-04-18      M Chinnaswamy Stadium        2   2.2
# ...          ...    ...         ...                        ...      ...   ...
# 218305   1304089   2022  2022-04-30  Brabourne Stadium, Mumbai        1  13.3
# 218317   1304089   2022  2022-04-30  Brabourne Stadium, Mumbai        1  15.3
# 218319   1304089   2022  2022-04-30  Brabourne Stadium, Mumbai        1  15.5
# 218321   1304089   2022  2022-04-30  Brabourne Stadium, Mumbai        1  16.1
# 218324   1304089   2022  2022-04-30  Brabourne Stadium, Mumbai        1  16.4
#
#                        batting_team           bowling_team  striker  \
# 132     Royal Challengers Bangalore  Kolkata Knight Riders  V Kohli
# 133     Royal Challengers Bangalore  Kolkata Knight Riders  V Kohli
# 134     Royal Challengers Bangalore  Kolkata Knight Riders  V Kohli
# 137     Royal Challengers Bangalore  Kolkata Knight Riders  V Kohli
# 138     Royal Challengers Bangalore  Kolkata Knight Riders  V Kohli
# ...                             ...                    ...      ...
# 218305  Royal Challengers Bangalore         Gujarat Titans  V Kohli
# 218317  Royal Challengers Bangalore         Gujarat Titans  V Kohli
# 218319  Royal Challengers Bangalore         Gujarat Titans  V Kohli
# 218321  Royal Challengers Bangalore         Gujarat Titans  V Kohli
# 218324  Royal Challengers Bangalore         Gujarat Titans  V Kohli
#
#        non_striker  ... extras  wides  noballs  byes  legbyes  penalty  \
# 132       W Jaffer  ...      0    NaN      NaN   NaN      NaN      NaN
# 133       W Jaffer  ...      4    NaN      NaN   NaN      4.0      NaN
# 134       W Jaffer  ...      0    NaN      NaN   NaN      NaN      NaN
# 137       W Jaffer  ...      0    NaN      NaN   NaN      NaN      NaN
# 138       W Jaffer  ...      0    NaN      NaN   NaN      NaN      NaN
# ...            ...  ...    ...    ...      ...   ...      ...      ...
# 218305  RM Patidar  ...      0    NaN      NaN   NaN      NaN      NaN
# 218317  GJ Maxwell  ...      0    NaN      NaN   NaN      NaN      NaN
# 218319  GJ Maxwell  ...      0    NaN      NaN   NaN      NaN      NaN
# 218321  GJ Maxwell  ...      0    NaN      NaN   NaN      NaN      NaN
# 218324  GJ Maxwell  ...      0    NaN      NaN   NaN      NaN      NaN
#
#         wicket_type  player_dismissed other_wicket_type other_player_dismissed
# 132             NaN               NaN               NaN                    NaN
# 133             NaN               NaN               NaN                    NaN
# 134             NaN               NaN               NaN                    NaN
# 137             NaN               NaN               NaN                    NaN
# 138          bowled           V Kohli               NaN                    NaN
# ...             ...               ...               ...                    ...
# 218305          NaN               NaN               NaN                    NaN
# 218317          NaN               NaN               NaN                    NaN
# 218319          NaN               NaN               NaN                    NaN
# 218321          NaN               NaN               NaN                    NaN
# 218324       bowled           V Kohli               NaN                    NaN
#
# [4999 rows x 22 columns]
